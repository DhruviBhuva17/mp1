# %%
# !pip install torch torchvision torchaudio
# !pip install opencv-python matplotlib
# !pip install yolov5

# %%
# !git clone https://github.com/ultralytics/yolov5
# %cd yolov5
# !pip install -r requirements.txt
# Out:
# C:\Users\HELLO\Documents\mp1\yolov5
# fatal: destination path 'yolov5' already exists and is not an empty directory.
# ...

# %%
import torch

# Load YOLOv5s pre-trained model
model = torch.hub.load('ultralytics/yolov5', 'yolov5s', pretrained=True)

# If you have your own pothole-trained weights:
# model = torch.hub.load('ultralytics/yolov5', 'custom', path='pothole_best.pt')
# Out:
# Using cache found in C:\Users\HELLO/.cache\torch\hub\ultralytics_yolov5_master
# YOLOv5  2026-3-21 Python-3.13.5 torch-2.10.0+cpu CPU
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients, 16.4 GFLOPs
# Adding AutoShape...

# %%
import torch

# Load YOLOv5s pre-trained model
model = torch.hub.load('ultralytics/yolov5', 'yolov5s', pretrained=True)

# If you have your own pothole-trained weights:
# model = torch.hub.load('ultralytics/yolov5', 'custom', path='pothole_best.pt')
# Out:
# Using cache found in C:\Users\HELLO/.cache\torch\hub\ultralytics_yolov5_master
# YOLOv5  2026-3-21 Python-3.13.5 torch-2.10.0+cpu CPU
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients, 16.4 GFLOPs
# Adding AutoShape...

# %%
import cv2
import os

folder = "C:/Users/HELLO/Documents/mp1/datasetyolo/images/train"

# Only image files filter
files = [f for f in os.listdir(folder) if f.endswith((".jpg", ".png", ".jpeg"))]

print("Images:", files)

img_path = os.path.join(folder, files[0])
print("Using:", img_path)

img = cv2.imread(img_path)

if img is None:
    print("Error loading image ❌")
else:
    print("Success ✅")
# Out:
# Images: ['img-100_jpg.rf.233751cac3399aa80b5e58a2afbb753a.jpg', 'img-101_jpg.rf.f213d98946c4f8858a5bf3200c89e39c.jpg', 'img-102_jpg.rf.16c56ff8f761aec963d9b57aa1b2d3fd.jpg', 'img-103_jpg.rf.09abf1a8e3477718e143255af3534d29.jpg', 'img-108_jpg.rf.a35e86abc558a98f252bfc10e49fd6d9.jpg', 'img-109_jpg.rf.add373710d0d425bd9340c33878e7d42.jpg', 'img-10_jpg.rf.eaceaaa6f119cf6eb49edc1bc92efaa2.jpg', 'img-110_jpg.rf.0390f81a2c5b2ad5676a8eb5b043d743.jpg', 'img-111_jpg.rf.d7e58630e249c45d8c1d564d847dc236.jpg', 'img-113_jpg.rf.31b41591a5e0c7b0aa02e133e79e1e2a.jpg', 'img-114_jpg.rf.b58901654a45a559a41ffaa25f1bf741.jpg', 'img-115_jpg.rf.ebc1ec2d7bb5caf80d06511d74f9e2da.jpg', 'img-117_jpg.rf.56a7e3b29e60b28e25b3f4a3c7817605.jpg', 'img-119_jpg.rf.5df904c99a0e765190d9421a4bf04bc6.jpg', 'img-11_jpg.rf.b7a2e18571a53d7512f101f224b7c794.jpg', 'img-121_jpg.rf.d202af2960b0bb1928539a6fcb3cdbfd.jpg', 'img-123_jpg.rf.8ae4c2726246a3dea5d41f6ba3a64639.jpg', 'img-124_jpg.rf.fdc89fc9a29a16b57ad54dd3c63e7952.jpg', '
# ...

# %%
# !pip install ultralytics

from ultralytics import YOLO

# %%
model = YOLO("yolov8n.pt")

# %%
model.train(
    data="C:/Users/HELLO/Documents/mp1/data.yaml",  # yaml no full path
    epochs=5,
    imgsz=300
)
# Out:
# Ultralytics 8.4.24  Python-3.13.5 torch-2.10.0+cpu CPU (Intel Core i5-8350U 1.70GHz)
# ...
